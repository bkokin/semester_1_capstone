# %%
#import pandas as pd 
#import csv

# %%
#data = pd.read_csv("tmdb.movies.csv")
#data.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   11/19/2010
# 1                      How to Train Your Dragon      28.734    3/26/2010
# 2                                    Iron Man 2      28.515     5/7/2010
# 3                                     Toy Story      28.005   11/22/1995
# 4                                     Inception      27.920    7/16/2010
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
#data.groupby ("original_language").mean()
# Out:
#                      Unnamed: 0             id  popularity  vote_average  \
# original_language
# ab                 15831.400000  347378.600000    0.977800      6.760000
# af                 24763.000000  502193.000000    4.814000      5.800000
# ar                 16040.193548  318630.000000    2.707484      6.903226
# bg                 15633.000000  316040.500000    1.047500      4.750000
# bn                 13739.750000  289980.750000    1.160000      6.375000
# ...                         ...            ...         ...           ...
# vi                 14820.285714  315237.571429    1.158429      7.000000
# xh                 22091.000000  428498.000000    1.564000      6.800000
# xx                 14365.166667  405629.083333    0.914167      6.854167
# yi                 21463.000000  428584.000000    3.614000      6.400000
# zh                 15004.508475  313827.757062    3.645927      6.285876
#
#                    vote_count
# original_language
# ...

# %%
#data[data < 1000].dropna()

#result = data[data['vote_count'] < 100] 
#print (result)

# %%
#data.original_language.value_counts()
# Out:
# en    23291
# fr      507
# es      455
# ru      298
# ja      265
#       ...
# ky        1
# ps        1
# si        1
# af        1
# kk        1
# Name: original_language, Length: 76, dtype: int64

# %%
import pandas as pd
df1 = pd.read_csv("tmdb.movies.csv")
df2 = pd.read_csv("tn.movie_budgets.csv")

# %%
df2
# Out:
#       id release_date                                        movie  \
# 0      1    18-Dec-09                                       Avatar
# 1      2    20-May-11  Pirates of the Caribbean: On Stranger Tides
# 2      3     7-Jun-19                                 Dark Phoenix
# 3      4     1-May-15                      Avengers: Age of Ultron
# 4      5    15-Dec-17            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5777  78    31-Dec-18                                       Red 11
# 5778  79     2-Apr-99                                    Following
# 5779  80    13-Jul-05                Return to the Land of Wonders
# 5780  81    29-Sep-15                         A Plague So Pleasant
# 5781  82     5-Aug-05                            My Date With Drew
#
#      production_budget domestic_gross  worldwide_gross
# 0        $425,000,000   $760,507,625   $2,776,345,279
# ...

# %%
df1.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   11/19/2010
# 1                      How to Train Your Dragon      28.734    3/26/2010
# 2                                    Iron Man 2      28.515     5/7/2010
# 3                                     Toy Story      28.005   11/22/1995
# 4                                     Inception      27.920    7/16/2010
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
#df1.rename(columns={"Unnamed: 0": "ids"})
# Out:
#          ids            genre_ids      id original_language  \
# 0          0      [12, 14, 10751]   12444                en
# 1          1  [14, 12, 16, 10751]   10191                en
# 2          2        [12, 28, 878]   10138                en
# 3          3      [16, 35, 10751]     862                en
# 4          4        [28, 878, 12]   27205                en
# ...      ...                  ...     ...               ...
# 26512  26512             [27, 18]  488143                en
# 26513  26513             [18, 53]  485975                en
# 26514  26514         [14, 28, 12]  381231                en
# 26515  26515      [10751, 12, 28]  366854                en
# 26516  26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   11/19/2010
# 1                          How to Train Your Dragon      28.734    3/26/2010
# ...

# %%
#df2.rename(columns={"movie": "original_title", "id" : "ids"})
# Out:
#       ids release_date                               original_title  \
# 0       1    18-Dec-09                                       Avatar
# 1       2    20-May-11  Pirates of the Caribbean: On Stranger Tides
# 2       3     7-Jun-19                                 Dark Phoenix
# 3       4     1-May-15                      Avengers: Age of Ultron
# 4       5    15-Dec-17            Star Wars Ep. VIII: The Last Jedi
# ...   ...          ...                                          ...
# 5777   78    31-Dec-18                                       Red 11
# 5778   79     2-Apr-99                                    Following
# 5779   80    13-Jul-05                Return to the Land of Wonders
# 5780   81    29-Sep-15                         A Plague So Pleasant
# 5781   82     5-Aug-05                            My Date With Drew
#
#      production_budget domestic_gross  worldwide_gross
# 0        $425,000,000   $760,507,625   $2,776,345,279
# ...

# %%
#inner_merged = pd.merge(df1, df2)
#inner_merged.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, genre_ids, id, original_language, original_title, popularity, release_date, title, vote_average, vote_count, movie, production_budget, domestic_gross, worldwide_gross]
# Index: []

# %%
#

# %%
#outer_join_df = df1.join(df2, rsuffix='_df2', how='outer')
#outer_join_df

# %%
#df2.rename(columns={"movie": "original_title", "id" : "ids"})
# Out:
#       ids release_date                               original_title  \
# 0       1    18-Dec-09                                       Avatar
# 1       2    20-May-11  Pirates of the Caribbean: On Stranger Tides
# 2       3     7-Jun-19                                 Dark Phoenix
# 3       4     1-May-15                      Avengers: Age of Ultron
# 4       5    15-Dec-17            Star Wars Ep. VIII: The Last Jedi
# ...   ...          ...                                          ...
# 5777   78    31-Dec-18                                       Red 11
# 5778   79     2-Apr-99                                    Following
# 5779   80    13-Jul-05                Return to the Land of Wonders
# 5780   81    29-Sep-15                         A Plague So Pleasant
# 5781   82     5-Aug-05                            My Date With Drew
#
#      production_budget domestic_gross  worldwide_gross
# 0        $425,000,000   $760,507,625   $2,776,345,279
# ...

# %%
#

# %%
#

# %%
#df2.merge(df1[['worldwide_gross', 'original_title']])

# %%
#

# %%
df3 = df1.join(df2, rsuffix='_df2', how='inner')
df3
# Out:
#       Unnamed: 0            genre_ids      id original_language  \
# 0              0      [12, 14, 10751]   12444                en
# 1              1  [14, 12, 16, 10751]   10191                en
# 2              2        [12, 28, 878]   10138                en
# 3              3      [16, 35, 10751]     862                en
# 4              4        [28, 878, 12]   27205                en
# ...          ...                  ...     ...               ...
# 5777        5777  [10749, 35, 18, 12]   44109                en
# 5778        5778                 [18]  119826                en
# 5779        5779             [53, 27]  192415                en
# 5780        5780          [35, 10751]  140228                nl
# 5781        5781      [16, 10751, 14]  167666                en
#
#                                     original_title  popularity release_date  \
# 0     Harry Potter and the Deathly Hallows: Part 1      33.533   11/19/2010
# ...

# %%
#

# %%
#

# %%
df3.original_language.value_counts()
# Out:
# en    4898
# fr     165
# es     102
# ru      96
# de      83
# hi      53
# ja      49
# it      49
# zh      31
# ko      26
# nl      21
# pt      20
# da      19
# cn      18
# no      17
# te      15
# sv      15
# pl      11
# th      10
# he      10
# fa       9
# hu       6
# tr       6
# ar       5
# cs       5
# xx       5
# tl       4
# fi       4
# ro       3
# el       3
# lt       3
# id       2
# sr       2
# ca       2
# lv       1
# bg       1
# bs       1
# uk       1
# ab       1
# ta       1
# mr       1
# nb       1
# si       1
# hr       1
# sl       1
# et       1
# is       1
# hz       1
# bo       1
# Name: original_language, dtype: int64

# %%
df3.groupby ("original_language").mean()
# Out:
#                     Unnamed: 0             id  popularity  vote_average  \
# original_language
# ab                 4505.000000  262896.000000    0.600000      9.000000
# ar                 3287.800000  112484.800000    1.465200      7.160000
# bg                 3560.000000   79159.000000    1.734000      6.600000
# bo                 4965.000000  105964.000000    0.600000      5.000000
# bs                 1148.000000   63834.000000    1.388000      7.000000
# ca                 3642.000000   71483.000000    2.412000      5.450000
# cn                 3060.277778   61017.333333    5.424611      6.377778
# cs                 2698.600000   47019.800000    1.438600      5.940000
# da                 2644.052632   61414.157895    4.428316      6.694737
# de                 2877.975904   82762.771084    3.196795      5.878313
# el                 3490.333333  167280.000000    4.022000      6.433333
# en                 2916.817272  130369.968967    3.386875      5.792303
# ...

# %%
result.groupby ("original_language").mean()
# Out:
#                     Unnamed: 0             id  popularity  vote_average  \
# original_language
# cn                 2508.166667   45053.000000    7.169333      7.016667
# da                 4055.500000   88122.166667    8.413167      6.800000
# de                 2008.000000   49807.400000    8.920200      6.460000
# en                 2790.074971   58291.637832   10.903814      6.284544
# es                 2532.277778   64945.611111    8.168333      6.911111
# fa                 2702.000000   60243.000000    8.510000      7.900000
# fi                  402.000000   48395.000000    5.704000      6.500000
# fr                 3028.549020   69647.490196    7.934745      6.498039
# hi                 2827.666667   66618.333333    7.576667      6.700000
# hu                 2761.000000   81401.000000    7.763000      7.900000
# id                 5325.000000  109003.500000    9.890000      7.600000
# it                 1877.875000   43954.375000    7.616625      6.637500
# ...

# %%
result = df3[df3['vote_count'] > 100] 
print (result)
# Out:
#       Unnamed: 0            genre_ids      id original_language  \
# 0              0      [12, 14, 10751]   12444                en
# 1              1  [14, 12, 16, 10751]   10191                en
# 2              2        [12, 28, 878]   10138                en
# 3              3      [16, 35, 10751]     862                en
# 4              4        [28, 878, 12]   27205                en
# ...          ...                  ...     ...               ...
# 5628        5628             [18, 53]   26405                en
# 5631        5631             [18, 14]  103328                fr
# 5638        5638                 [27]  119278                en
# 5641        5641        [27, 878, 53]  123105                en
# 5645        5645             [80, 18]   63310                nl
#
#                                     original_title  popularity release_date  \
# 0     Harry Potter and the Deathly Hallows: Part 1      33.533   11/19/2010
# ...

# %%
#

# %%
import seaborn as sns
sns.scatterplot(x="original_language", y="worldwide_gross", data=result, hue = "vote_count");

#plt.title ("")
#plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

#Note: maybe subtract worldwide gross from production budget to get the worldwide profit 
       # find popular language and any correlation to the worldwide profit

# %%
import seaborn as sns
sns.scatterplot(x="original_language", y="worldwide_gross", data=result, hue = "popularity");

# %%
#result.worldwide_gross = result.worldwide_gross.str.replace(',', '').str.replace('$', '').astype("int64")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-110-76ed1d250f3b> in <module>
# ----> 1 result.worldwide_gross = result.worldwide_gross.str.replace(',', '').str.replace('$', '').astype("int64")
#
# ~\AppData\Local\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5133             or name in self._accessors
#    5134         ):
# -> 5135             return object.__getattribute__(self, name)
#    5136         else:
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\AppData\Local\anaconda3\envs\learn-env\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
# ...

# %%
#result.production_budget = result.production_budget = result.production_budget.str.replace(',', '').str.replace('$', '').astype("int64")

#result.production_budget.str.replace(',', '').str.replace('$', '').astype("int64")
#result.production_budget = result.production_budget.str.replace(',', '').str.replace('$', '').astype("int64")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-111-4b806c7e3de3> in <module>
# ----> 1 result.production_budget = result.production_budget.str.replace(',', '').str.replace('$', '').astype("int64")
#       2
#       3 #result.production_budget.str.replace(',', '').str.replace('$', '').astype("int64")
#       4 #result.production_budget = result.production_budget.str.replace(',', '').str.replace('$', '').astype("int64")
#
# ~\AppData\Local\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5133             or name in self._accessors
#    5134         ):
# -> 5135             return object.__getattribute__(self, name)
#    5136         else:
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ...

# %%
print(result)
# Out:
#       Unnamed: 0            genre_ids      id original_language  \
# 0              0      [12, 14, 10751]   12444                en
# 1              1  [14, 12, 16, 10751]   10191                en
# 2              2        [12, 28, 878]   10138                en
# 3              3      [16, 35, 10751]     862                en
# 4              4        [28, 878, 12]   27205                en
# ...          ...                  ...     ...               ...
# 5628        5628             [18, 53]   26405                en
# 5631        5631             [18, 14]  103328                fr
# 5638        5638                 [27]  119278                en
# 5641        5641        [27, 878, 53]  123105                en
# 5645        5645             [80, 18]   63310                nl
#
#                                     original_title  popularity release_date  \
# 0     Harry Potter and the Deathly Hallows: Part 1      33.533   11/19/2010
# ...

# %%
#result["worldwide_profit"] = result["worldwide_gross"] - result["production_budget"]
#result

# %%
#import seaborn as sns
#sns.scatterplot(x="original_language", y="worldwide_profit", data=result, hue = "vote_count");

# %%
import pandas as pd
import matplotlib.pyplot as plot
result.plot.bar(x="original_language", y="popularity", rot=0, title="Language with the most popularity");
plot.show(block=True);

# %%
import pandas as pd
import matplotlib.pyplot as plot
# %matplotlib inline

df3.groupby(["original_language"])["popularity"].sum().sort_values().plot(kind="barh", figsize=(15, 8))
plt.title("Total Language Popularity")
plt.xlabel("Popularity")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-2610d31dfa71> in <module>
#       4
#       5 df3.groupby(["original_language"])["popularity"].sum().sort_values().plot(kind="barh", figsize=(15, 8))
# ----> 6 plt.title("Total Language Popularity")
#       7 plt.xlabel("Popularity")
#
# NameError: name 'plt' is not defined

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5782 entries, 0 to 5781
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         5782 non-null   int64
#  1   genre_ids          5782 non-null   object
#  2   id                 5782 non-null   int64
#  3   original_language  5782 non-null   object
#  4   original_title     5782 non-null   object
#  5   popularity         5782 non-null   float64
#  6   release_date       5782 non-null   object
#  7   title              5782 non-null   object
#  8   vote_average       5782 non-null   float64
#  9   vote_count         5782 non-null   int64
#  10  id_df2             5782 non-null   int64
#  11  release_date_df2   5782 non-null   object
#  12  movie              5782 non-null   object
#  13  production_budget  5782 non-null   object
#  14  domestic_gross     5782 non-null   object
#  15  worldwide_gross    5782 non-null   object
# ...

# %%
df2.worldwide_gross = df2.worldwide_gross.str.replace(',', '').str.replace('$', '').astype("int64")

# %%
df2.production_budget = df2.production_budget.str.replace(',', '').str.replace('$', '').astype("int64")

# %%
print(df2)
# Out:
#       id release_date                                        movie  \
# 0      1    18-Dec-09                                       Avatar
# 1      2    20-May-11  Pirates of the Caribbean: On Stranger Tides
# 2      3     7-Jun-19                                 Dark Phoenix
# 3      4     1-May-15                      Avengers: Age of Ultron
# 4      5    15-Dec-17            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5777  78    31-Dec-18                                       Red 11
# 5778  79     2-Apr-99                                    Following
# 5779  80    13-Jul-05                Return to the Land of Wonders
# 5780  81    29-Sep-15                         A Plague So Pleasant
# 5781  82     5-Aug-05                            My Date With Drew
#
#       production_budget domestic_gross  worldwide_gross
# 0             425000000  $760,507,625        2776345279
# ...

# %%
df2["worldwide_profit"] = df2["worldwide_gross"] - df2["production_budget"]
df2
# Out:
#       id release_date                                        movie  \
# 0      1    18-Dec-09                                       Avatar
# 1      2    20-May-11  Pirates of the Caribbean: On Stranger Tides
# 2      3     7-Jun-19                                 Dark Phoenix
# 3      4     1-May-15                      Avengers: Age of Ultron
# 4      5    15-Dec-17            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5777  78    31-Dec-18                                       Red 11
# 5778  79     2-Apr-99                                    Following
# 5779  80    13-Jul-05                Return to the Land of Wonders
# 5780  81    29-Sep-15                         A Plague So Pleasant
# 5781  82     5-Aug-05                            My Date With Drew
#
#       production_budget domestic_gross  worldwide_gross  worldwide_profit
# 0             425000000  $760,507,625        2776345279        2351345279
# ...

# %%
df3 = df1.join(df2, rsuffix='_df2', how='inner')
df3
# Out:
#       Unnamed: 0            genre_ids      id original_language  \
# 0              0      [12, 14, 10751]   12444                en
# 1              1  [14, 12, 16, 10751]   10191                en
# 2              2        [12, 28, 878]   10138                en
# 3              3      [16, 35, 10751]     862                en
# 4              4        [28, 878, 12]   27205                en
# ...          ...                  ...     ...               ...
# 5777        5777  [10749, 35, 18, 12]   44109                en
# 5778        5778                 [18]  119826                en
# 5779        5779             [53, 27]  192415                en
# 5780        5780          [35, 10751]  140228                nl
# 5781        5781      [16, 10751, 14]  167666                en
#
#                                     original_title  popularity release_date  \
# 0     Harry Potter and the Deathly Hallows: Part 1      33.533   11/19/2010
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (10,6)) 


sns.scatterplot(x="original_language", y="worldwide_profit",  data=df3, hue = "popularity");

plt.xticks(fontsize = 12, rotation = 60);

#change the names of languages xticklabel

# %%
df4 = df3[df3['vote_count'] > 100] 
print (df4)
# Out:
#       Unnamed: 0            genre_ids      id original_language  \
# 0              0      [12, 14, 10751]   12444                en
# 1              1  [14, 12, 16, 10751]   10191                en
# 2              2        [12, 28, 878]   10138                en
# 3              3      [16, 35, 10751]     862                en
# 4              4        [28, 878, 12]   27205                en
# ...          ...                  ...     ...               ...
# 5628        5628             [18, 53]   26405                en
# 5631        5631             [18, 14]  103328                fr
# 5638        5638                 [27]  119278                en
# 5641        5641        [27, 878, 53]  123105                en
# 5645        5645             [80, 18]   63310                nl
#
#                                     original_title  popularity release_date  \
# 0     Harry Potter and the Deathly Hallows: Part 1      33.533   11/19/2010
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (10,6)) 


sns.scatterplot(x="original_language", y="worldwide_profit",  data=df3, hue = "vote_count");

plt.xticks(fontsize = 12, rotation = 60);

#change the names of languages xticklabel
